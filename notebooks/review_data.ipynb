# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../usdvnd/processed/cleaned.csv")
df.index = df['Ngày']
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#             Lần cuối       Mở      Cao     Thấp  % Thay đổi        Ngày
# Ngày
# 1994-08-05   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-05
# 1994-08-06   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-06
# 1994-08-07   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-07
# 1994-08-08   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-08
# 1994-08-09   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-09
# ...              ...      ...      ...      ...         ...         ...
# 2025-11-05   26322.5  26319.5  26345.0  26302.5        0.01  2025-11-05
# 2025-11-06   26315.0  26323.5  26338.0  26298.0       -0.03  2025-11-06
# 2025-11-07   26310.0  26314.5  26330.0  26293.0       -0.02  2025-11-07
# 2025-11-08   26310.0  26314.5  26330.0  26293.0        0.00  2025-11-08
# 2025-11-09   26310.0  26310.0  26310.0  26310.0       -0.00  2025-11-09
#
# [11420 rows x 6 columns]

# %%
plt.figure(figsize=(18, 8))
plt.plot(df['Lần cuối'])
plt.show()

# %%
df[-2:][['Cao', 'Thấp', 'Mở']].to_dict(orient='records')

# %%
import boto3
import pandas as pd
import io
import os
from dotenv import load_dotenv

load_dotenv()

REGION = os.getenv("REGION")
S3_BUCKET_NAME = os.getenv("S3_BUCKET")
DATA_PATH = "data/cleaned_features_regression.csv"
REGION, S3_BUCKET_NAME, DATA_PATH
# Out:
# ('us-east-1', 'usd-vnd-prediction', 'data/cleaned_features_regression.csv')

# %%
def load_data_from_s3():
    s3 = boto3.client('s3', region_name=REGION)
    obj = s3.get_object(Bucket=S3_BUCKET_NAME, Key=DATA_PATH)
    # decode file
    file_content = obj['Body'].read().decode('utf-8')
    # convert to dataframe
    df = pd.read_csv(io.StringIO(file_content))
    df.set_index('Ngày', inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

load_data_from_s3()
# Out:
#             Lần cuối       Mở      Cao     Thấp  % Thay đổi  Lần cuối 1  \
# Ngày
# 1994-09-03   10988.0  10988.0  10988.0  10988.0        0.00     10988.0
# 1994-09-04   10988.0  10988.0  10988.0  10988.0        0.00     10988.0
# 1994-09-05   10988.0  10988.0  10988.0  10988.0        0.00     10988.0
# 1994-09-06   10988.0  10988.0  10988.0  10988.0        0.00     10988.0
# 1994-09-07   10988.0  10988.0  10988.0  10988.0        0.00     10988.0
# ...              ...      ...      ...      ...         ...         ...
# 2025-11-04   26320.0  26316.0  26341.0  26302.5        0.03     26312.0
# 2025-11-05   26322.5  26319.5  26345.0  26302.5        0.01     26320.0
# 2025-11-06   26315.0  26323.5  26338.0  26298.0       -0.03     26322.5
# 2025-11-07   26310.0  26314.5  26330.0  26293.0       -0.02     26315.0
# 2025-11-08   26310.0  26314.5  26330.0  26293.0        0.00     26310.0
#
#             % Thay đổi 1  Lần cuối 3  Lần cuối 7          MA 7         MA 30  \
# Ngày
# ...

# %%
import os 
from dotenv import load_dotenv
from joblib import load
import boto3
import pandas as pd
import io

load_dotenv()

DATA_PATH = os.getenv("DATA_PATH_S3")
DEFAULT_MODEL_PATH = os.getenv("MODEL_PATH_S3")
S3_BUCKET = os.getenv("S3_BUCKET")
REGION = os.getenv("REGION")

def load_data_from_s3():
    s3 = boto3.client('s3', region_name=REGION)
    obj = s3.get_object(Bucket=S3_BUCKET, Key=DATA_PATH)
    file_content = obj['Body'].read().decode('utf-8')
    df = pd.read_csv(io.StringIO(file_content))
    df.set_index('Ngày', inplace=True)
    df.index = pd.to_datetime(df.index)
    return df

def load_model_from_s3():
    s3 = boto3.client('s3', region_name=REGION)
    obj = s3.get_object(Bucket=S3_BUCKET, Key=DEFAULT_MODEL_PATH)
    print(obj)
    model = load(io.BytesIO(obj['Body'].read()))
    print(model)
    return model

DEFAULT_MODEL_PATH
# Out:
# 'model/best_model.pkl'

# %%
load_model_from_s3()
# Out:
# {'ResponseMetadata': {'RequestId': '0878Z4AFBRQFA3F5', 'HostId': 'mieewbtKj6i7/62YrLwhU5MYql4ZLTMdkxN7BHxbHWkdwwtghJIB1sjkI/acw39EuVjKO2Hre0o=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'mieewbtKj6i7/62YrLwhU5MYql4ZLTMdkxN7BHxbHWkdwwtghJIB1sjkI/acw39EuVjKO2Hre0o=', 'x-amz-request-id': '0878Z4AFBRQFA3F5', 'date': 'Wed, 12 Nov 2025 09:19:59 GMT', 'last-modified': 'Tue, 11 Nov 2025 15:42:17 GMT', 'etag': '"c35f7f763e2a99d153c6b0ba660115bd"', 'x-amz-checksum-crc32': 'Zep1Og==', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'accept-ranges': 'bytes', 'content-type': 'binary/octet-stream', 'content-length': '366084', 'server': 'AmazonS3'}, 'ChecksumAlgorithm': 'crc32', 'RetryAttempts': 0}, 'AcceptRanges': 'bytes', 'LastModified': datetime.datetime(2025, 11, 11, 15, 42, 17, tzinfo=tzutc()), 'ContentLength': 366084, 'ETag': '"c35f7f763e2a99d153c6b0ba660115bd"', 'ChecksumCRC32': 'Zep1Og==', 'ChecksumType': 'FULL_OBJECT', 'ContentType': 'binary/octe
# ...

# %%
import requests

URL = "http://localhost:8000/predict/30"

response = requests.get(URL)
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Documents/usd-vnd-prediction/.venv/lib/python3.13/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.local/share/uv/python/cpython-3.13.9-linux-x86_64-gnu/lib/python3.13/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# ...

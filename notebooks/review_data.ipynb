# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../usdvnd/usdvnd_cleaned.csv")
df.index = df['Ngày']
df.index = pd.to_datetime(df.index)

# %%
df
# Out:
#             Lần cuối       Mở      Cao     Thấp  % Thay đổi        Ngày
# Ngày
# 1994-08-05   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-05
# 1994-08-06   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-06
# 1994-08-07   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-07
# 1994-08-08   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-08
# 1994-08-09   10981.0  10981.0  10981.0  10981.0        0.00  1994-08-09
# ...              ...      ...      ...      ...         ...         ...
# 2025-11-03   26312.0  26306.0  26326.5  26275.0       -0.01  2025-11-03
# 2025-11-04   26320.0  26316.0  26341.0  26302.5        0.03  2025-11-04
# 2025-11-05   26322.5  26319.5  26345.0  26302.5        0.01  2025-11-05
# 2025-11-06   26315.0  26323.5  26338.0  26298.0       -0.03  2025-11-06
# 2025-11-07   26310.0  26314.5  26330.0  26293.0       -0.02  2025-11-07
#
# [11418 rows x 6 columns]

# %%
plt.figure(figsize=(18, 8))
plt.plot(df['Lần cuối'])
plt.show()
